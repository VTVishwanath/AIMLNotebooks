# %% [markdown]
# # Clustering K-Means

# %%
import random
import numpy as np
import matplotlib.pyplot as plt

# %%
from sklearn.datasets import make_blobs
# %matplotlib inline

# %%
from sklearn.cluster import KMeans

# %%
np.random.seed(42)

# %%
X,y = make_blobs(n_samples=5000, centers=[[3,3],[-2,-1],[2,-3],[1,1]], cluster_std=0.8)

# %%
X[0:5]
# Out:
# array([[-1.49637633, -1.64345261],
#        [ 0.50530798,  0.36408508],
#        [ 1.1709526 , -3.16276891],
#        [ 1.76967514, -2.80396907],
#        [-2.33432764, -2.6206463 ]])

# %%
y[0:5]
# Out:
# array([1, 3, 2, 2, 1])

# %%
plt.scatter(X[:,0],X[:,1],marker='+')
plt.show()

# %%
k_means = KMeans(n_clusters=4,n_init=25)

# %%
k_means.fit(X)
# Out:
# KMeans(n_clusters=4, n_init=25)

# %%
k_means_labels = k_means.labels_
k_means_labels
# Out:
# array([1, 2, 3, ..., 3, 1, 1])

# %%
k_means_cluster_centers = k_means.cluster_centers_
k_means_cluster_centers
# Out:
# array([[ 3.02462877,  3.05633385],
#        [-2.01959454, -1.03207605],
#        [ 0.9852085 ,  0.99640049],
#        [ 1.99039519, -3.04171042]])

# %%
fig = plt.figure(figsize=(6,4))
colors = plt.cm.Spectral(np.linspace(0,1,len(set(k_means_labels))))

ax = fig.add_subplot(1,1,1)

for k, col in zip(range(len([[ 3.02462877,  3.05633385],
       [-2.01959454, -1.03207605],
       [ 0.9852085 ,  0.99640049],
       [ 1.99039519, -3.04171042]])),colors):
    print(k, col)
    my_member = (k_means_labels==k)
    cluster_center = k_means_cluster_centers[k]
    ax.plot(X[my_member,0],X[my_member,1],'w',markerfacecolor=col, marker='.',markersize=6)
    ax.plot(cluster_center[0],cluster_center[1],'o',markerfacecolor=col, markeredgecolor='k',markersize=6)

ax.set_title('KMeans')
ax.set_xticks(())
ax.set_yticks(())

plt.show()
# Out:
# 0 [0.61960784 0.00392157 0.25882353 1.        ]
# 1 [0.99346405 0.74771242 0.43529412 1.        ]
# 2 [0.74771242 0.89803922 0.62745098 1.        ]
# 3 [0.36862745 0.30980392 0.63529412 1.        ]

# %%
zip(range(len([[ 3.02462877,  3.05633385],
       [-2.01959454, -1.03207605],
       [ 0.9852085 ,  0.99640049],
       [ 1.99039519, -3.04171042]])),colors)

# %%
range(len([[ 3.02462877,  3.05633385],
       [-2.01959454, -1.03207605],
       [ 0.9852085 ,  0.99640049],
       [ 1.99039519, -3.04171042]]))
# Out:
# range(0, 4)

# %%
len([[ 3.02462877,  3.05633385],
       [-2.01959454, -1.03207605],
       [ 0.9852085 ,  0.99640049],
       [ 1.99039519, -3.04171042]])
# Out:
# 4

# %%
colors
# Out:
# array([[0.61960784, 0.00392157, 0.25882353, 1.        ],
#        [0.99346405, 0.74771242, 0.43529412, 1.        ],
#        [0.74771242, 0.89803922, 0.62745098, 1.        ],
#        [0.36862745, 0.30980392, 0.63529412, 1.        ]])
